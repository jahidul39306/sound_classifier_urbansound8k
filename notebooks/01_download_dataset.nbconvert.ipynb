# %%
! pip install kaggle
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
! kaggle datasets download -d chrisfilo/urbansound8k -p ../data/raw/
! unzip ../data/raw/urbansound8k.zip -d ../data/raw/urbansound8k/
# Out:
# /bin/bash: line 1: kaggle: command not found
# unzip:  cannot find or open ../data/raw/urbansound8k.zip, ../data/raw/urbansound8k.zip.zip or ../data/raw/urbansound8k.zip.ZIP.
